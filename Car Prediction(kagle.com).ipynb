# %%
#predict the price of car
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
df=pd.read_csv(r'C:\Users\Shubhamay\Documents\car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#unique value in seller type
print(df["Seller_Type"].unique())
#unique value in Transmission
print(df["Transmission"].unique())
#unique value in Owner
print(df["Owner"].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
#checking missing or null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#describing car
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset=df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['current_year']=2020

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  current_year
# 0         Manual      0          2020
# ...

# %%
#We create 'no of year ' column to calculate depriciation charge
final_dataset['no_of_year']=final_dataset['current_year']-final_dataset['Year']

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  current_year  no_of_year
# ...

# %%
final_dataset.drop(['Year','current_year'],axis=1,inplace=True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  no_of_year
# 0         Manual      0           6
# 1         Manual      0           7
# 2         Manual      0           3
# ...

# %%
final_dataset=pd.get_dummies(final_dataset)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  no_of_year  \
# 0             3.35           5.59       27000      0           6
# 1             4.75           9.54       43000      0           7
# 2             7.25           9.85        6900      0           3
# 3             2.85           4.15        5200      0           9
# 4             4.60           6.87       42450      0           6
# ..             ...            ...         ...    ...         ...
# 296           9.50          11.60       33988      0           4
# 297           4.00           5.90       60000      0           5
# 298           3.35          11.00       87934      0          11
# 299          11.50          12.50        9000      0           3
# 300           5.30           5.90        5464      0           4
#
#      Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                0                 0                 1                   1
# ...

# %%
#To see corelation between data 
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_of_year                  -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_CNG               -0.025164      -0.011500    0.012223 -0.014272
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Dealer           0.550724       0.512030    0.101419 -0.124269
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Automatic       0.367128       0.348715    0.162510  0.050316
# ...

# %%
#to plot corelation between dataset
import seaborn as sns
sns.pairplot(final_dataset)

# %%
import matplotlib.pyplot as plt

top_cor_feature=corrmat.index
plt.figure(figsize=(10,10))
sns.heatmap(final_dataset.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  no_of_year  \
# 0             3.35           5.59       27000      0           6
# 1             4.75           9.54       43000      0           7
# 2             7.25           9.85        6900      0           3
# 3             2.85           4.15        5200      0           9
# 4             4.60           6.87       42450      0           6
# ..             ...            ...         ...    ...         ...
# 296           9.50          11.60       33988      0           4
# 297           4.00           5.90       60000      0           5
# 298           3.35          11.00       87934      0          11
# 299          11.50          12.50        9000      0           3
# 300           5.30           5.90        5464      0           4
#
#      Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                0                 0                 1                   1
# ...

# %%
# independent feature
X=final_dataset.iloc[:,1:]
#dependent_feature
y=final_dataset.iloc[:,0]

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  no_of_year  Fuel_Type_CNG  \
# 0             5.59       27000      0           6              0
# 1             9.54       43000      0           7              0
# 2             9.85        6900      0           3              0
# 3             4.15        5200      0           9              0
# 4             6.87       42450      0           6              0
# ..             ...         ...    ...         ...            ...
# 296          11.60       33988      0           4              0
# 297           5.90       60000      0           5              0
# 298          11.00       87934      0          11              0
# 299          12.50        9000      0           3              0
# 300           5.90        5464      0           4              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                   0                 1                   1
# 1                   1                 0                   1
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
#feature importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [3.96988881e-01 4.09137538e-02 7.56727708e-04 7.36892900e-02
#  8.85711026e-05 2.06037444e-01 1.89366570e-02 1.24147545e-01
#  1.90073561e-03 5.22350318e-02 8.43053632e-02]

# %%
#plot graphshowing top 10 important feature
feat_importance=pd.Series(model.feature_importances_,index=X.columns)
feat_importance.nlargest(10).plot(kind='barh')
plt.show()
#here present price is most important feature and
#and no of year last important feature
#it is for just showing

# %%
#now we do train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#      Present_Price  Kms_Driven  Owner  no_of_year  Fuel_Type_CNG  \
# 261           5.97        5600      0           4              0
# 215           9.40       36100      0           8              0
# 275          13.60       30753      0           4              0
# 103           1.60        1200      0           3              0
# 185           0.58        1900      0          12              0
# ..             ...         ...    ...         ...            ...
# 159           0.51        4000      0           3              0
# 288          13.60       34000      0           5              0
# 2             9.85        6900      0           3              0
# 212          13.60       22671      0           4              0
# 223           9.40       61381      0           5              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 261                 0                 1                   1
# 215                 0                 1                   1
# ...

# %%
#crete model using decision tree regressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
y_train
# Out:
# 261     5.50
# 215     4.50
# 275    10.90
# 103     1.45
# 185     0.25
#        ...
# 159     0.45
# 288     8.40
# 2       7.25
# 212    11.25
# 223     8.25
# Name: Selling_Price, Length: 240, dtype: float64

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
#score of our prediction
dt.score(X_train,y_train)
# Out:
# 1.0

# %%
#to do predict
prediction=dt.predict(X_test)
prediction
# Out:
# array([ 7.45,  4.1 ,  0.2 ,  5.25,  4.5 , 18.  ,  8.65,  5.25,  4.  ,
#         1.15,  0.3 ,  6.6 ,  0.9 ,  0.45,  6.75,  8.55, 11.75,  4.6 ,
#         0.3 , 12.5 ,  8.25,  4.65,  5.25,  2.95,  6.  ,  0.48,  4.  ,
#         3.75,  4.4 ,  1.25,  0.5 ,  8.65,  9.65,  0.38,  2.95,  6.15,
#         0.4 ,  5.2 ,  3.51,  4.1 ,  5.25,  2.9 ,  0.65,  9.1 ,  3.1 ,
#         5.95,  3.45,  9.1 ,  6.7 ,  0.9 ,  1.35, 18.  ,  1.95,  7.45,
#         3.6 ,  3.45,  3.65,  3.51,  5.4 ,  4.5 ,  0.5 ])

# %%
#to cheak distribution of our prediction
#distribution is normal distribution that means our prediction is pretty much good
import seaborn as sns
sns.distplot(y_test-prediction)

# %%
#plot scatter plot of prediction
#it is linear mean our prediction is prettymuch good
plt.scatter(y_test,prediction,color='r')

# %%
#
